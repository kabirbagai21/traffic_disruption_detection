# %%
'''
 * The Recognize Anything Plus Model (RAM++) inference on unseen classes
 * Written by Xinyu Huang
'''
import argparse
import numpy as np
import random
from torchvision.transforms import Normalize, Compose, Resize, ToTensor

import torch

from PIL import Image
from ram.models import ram_plus
from ram import inference_ram_openset as inference
from ram import get_transform

from ram.utils import build_openset_llm_label_embedding
from torch import nn
import json

# parser = argparse.ArgumentParser(
#     description='Tag2Text inferece for tagging and captioning')
# parser.add_argument('--image',
#                     metavar='DIR',
#                     help='path to dataset',
#                     default='images/openset_example.jpg')
# parser.add_argument('--pretrained',
#                     metavar='DIR',
#                     help='path to pretrained model',
#                     default='pretrained/ram_plus_swin_large_14m.pth')
# parser.add_argument('--image-size',
#                     default=384,
#                     type=int,
#                     metavar='N',
#                     help='input image size (default: 448)')
# parser.add_argument('--llm_tag_des',
#                     metavar='DIR',
#                     help='path to LLM tag descriptions',
#                     default='datasets/openimages_rare_200/openimages_rare_200_llm_tag_descriptions.json')

# args = parser.parse_args()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f"device using: {device}")


def convert_to_rgb(image):
    return image.convert("RGB")


# transform = get_transform(image_size=384)
transform = Compose([
        convert_to_rgb,
        Resize((2160, 3840)),
        ToTensor(),
    ])

transform2 = Compose([
        Resize((384, 384)),
        Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

#######load model
model = ram_plus(pretrained='pretrained/ram_plus_swin_large_14m.pth',
                         image_size=384,
                         vit='swin_l')

#######set openset interference

print('Building tag embedding:')
with open('datasets/openimages_rare_200/openimages_rare_200_llm_tag_descriptions.json', 'rb') as fo:
    llm_tag_des = json.load(fo)
openset_label_embedding, openset_categories = build_openset_llm_label_embedding(llm_tag_des)

model.tag_list = np.array(openset_categories)

model.label_embed = nn.Parameter(openset_label_embedding.float())

model.num_class = len(openset_categories)
# the threshold for unseen categories is often lower
model.class_threshold = torch.ones(model.num_class) * 0.5
#######

model.eval()

model = model.to(device)
# Out:
# /home/af3410/.local/lib/python3.11/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/af3410/.local/lib/python3.11/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# device using: cuda
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# --------------
# pretrained/ram_plus_swin_large_14m.pth
# --------------
# load checkpoint from pretrained/ram_plus_swin_large_14m.pth
# vit: swin_l
# Building tag embedding:
# Creating pretrained CLIP model
# 100%|██████████| 14/14 [00:00<00:00, 28.28it/s]

# %%
image = transform(Image.open('../2ndFloorData/images/L2ndFloor-D-2021-12-22_T-22_00_01.jpg')).unsqueeze(0).to(device)

res = inference(transform2(image), model)
print("Image Tags: ", res)
# Out:
# Image Tags:  Traffic cone

# %%
transform2(image).shape
# Out:
# torch.Size([1, 3, 384, 384])

# %%
import torch

def Slicing(img, window_height, window_width, stride):
    batch_size, num_channels, img_height, img_width = img.shape
    print(f"Image shape: {img.shape}")
    
    slices = []
    for i in range(0, img_height - window_height + 1, int(stride * window_height)):
        for j in range(0, img_width - window_width + 1, int(stride * window_width)):
            img_segment = img[:, :, i:i+window_height, j:j+window_width]
            slices.append(img_segment)
    
    return torch.cat(slices, dim=0)

sliced = Slicing(image, 512, 512, stride=0.5)
sliced.shape
# Out:
# Image shape: torch.Size([1, 3, 2160, 3840])
# torch.Size([98, 3, 512, 512])

# %%
transform2(sliced).shape
# Out:
# torch.Size([98, 3, 384, 384])

# %%
with torch.no_grad():
    tags = model.generate_tag_openset_prob(transform2(sliced))

# %%
len(tags)
# Out:
# 98

# %%
def get_max_probabilities(list_of_dicts):
    max_probs = {}

    for d in list_of_dicts:
        for tag, prob in d.items():
            if tag not in max_probs:
                max_probs[tag] = prob
            else:
                max_probs[tag] = max(max_probs[tag], prob)

    return max_probs

# %%
max_probs = get_max_probabilities(tags)
max_probs
# Out:
# {'Barricade': 0.8060165643692017,
#  'Traffic cone': 0.9115189909934998,
#  'Traffic barrel': 0.7850309014320374,
#  'Scaffold': 0.5142012238502502,
#  'Trailer truck': 0.4665645658969879,
#  'Police car': 0.8906596899032593,
#  'Ambulance': 0.748346209526062,
#  'Firecar': 0.6207081079483032,
#  'Excavator': 0.3295373320579529,
#  'Construction truck': 0.5063043832778931,
#  'Car moving truck': 0.5681664347648621,
#  'Offroad parking': 0.4186611473560333,
#  'Construction car': 0.5562924742698669,
#  'Construction worker': 0.690403163433075}

# %%
import glob
import os
from tqdm import tqdm

image_dir = '../2ndFloorData/images/'
image_paths = glob.glob(os.path.join(image_dir, '*.*'))

image_paths = [p for p in image_paths if p.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]

results = {}
for img_path in tqdm(image_paths):
    file_name = os.path.basename(img_path) 
    image = transform(Image.open(img_path)).unsqueeze(0).to(device)
    sliced = Slicing(image, 512, 512, stride=0.5)
    with torch.no_grad():
        tags = model.generate_tag_openset_prob(transform2(sliced))
    max_probs = get_max_probabilities(tags)
    results[file_name] = max_probs

# %%
results
# Out:
# {'L2ndFloor-D-2022-01-28_T-00_30_01.jpg': {'Barricade': 0.8109170198440552,
#   'Traffic cone': 0.9033704996109009,
#   'Traffic barrel': 0.7182284593582153,
#   'Scaffold': 0.5912752151489258,
#   'Trailer truck': 0.5170974135398865,
#   'Police car': 0.8763160109519958,
#   'Ambulance': 0.6897092461585999,
#   'Firecar': 0.541136622428894,
#   'Excavator': 0.3267523944377899,
#   'Construction truck': 0.5438394546508789,
#   'Car moving truck': 0.5371878147125244,
#   'Offroad parking': 0.43454355001449585,
#   'Construction car': 0.5737396478652954,
#   'Construction worker': 0.6603937745094299},
#  'L2ndFloor-D-2022-02-27_T-03_30_01.jpg': {'Barricade': 0.7447649836540222,
#   'Traffic cone': 0.749268651008606,
#   'Traffic barrel': 0.6054819822311401,
#   'Scaffold': 0.4709216356277466,
#   'Trailer truck': 0.8329820036888123,
#   'Police car': 0.8434134721755981,
#   'Ambulance': 0.8311448097229004,
#   'Firecar': 0.6064722537994385,
#   'Excavator': 0.32304590940475464,
#   'Construction truck': 0.8629425168037415,
#   'Car moving truck': 0.7142212986946106,
#   'Offroad parking': 0.4929136633872986,
#   'Construction car': 0.6855145692825317,
#   'Construction worker': 0.5202254056930542},
#  'L2ndFloor-D-2022-02-06_T-18_30_01.jpg': {'Barricade': 0.6968656182289124,
#   'Traffic cone': 0.6184894442558289,
#   'Traffic barrel': 0.5375450849533081,
#   'Scaffold': 0.8037262558937073,
#   'Trailer truck': 0.5606802701950073,
#   'Police car': 0.8600768446922302,
#   'Ambulance': 0.6462112665176392,
#   'Firecar': 0.44720733165740967,
#   'Excavator': 0.8250269293785095,
#   'Construction truck': 0.7813896536827087,
#   'Car moving truck': 0.6022242307662964,
#   'Offroad parking': 0.4367465376853943,
#   'Construction car': 0.7586208581924438,
#   'Construction worker': 0.7426405549049377},
#  'L2ndFloor-D-2022-02-25_T-00_00_02.jpg': {'Barricade': 0.7077585458755493,
#   'Traffic cone': 0.7009893655776978,
#   'Traffic barrel': 0.6393033266067505,
#   'Scaffold': 0.46197497844696045,
#   'Trailer truck': 0.6560734510421753,
#   'Police car': 0.8824552297592163,
#   'Ambulance': 0.8621426224708557,
#   'Firecar': 0.6091503500938416,
#   'Excavator': 0.3058875501155853,
#   'Construction truck': 0.6415209174156189,
#   'Car moving truck': 0.7025108933448792,
#   'Offroad parking': 0.5107477307319641,
#   'Construction car': 0.6062809228897095,
#   'Construction worker': 0.5305732488632202},
#  'L2ndFloor-D-2022-03-21_T-18_30_01.jpg': {'Barricade': 0.7821087837219238,
#   'Traffic cone': 0.8304035663604736,
#   'Traffic barrel': 0.6443259716033936,
#   'Scaffold': 0.8581591844558716,
#   'Trailer truck': 0.5156611204147339,
#   'Police car': 0.6370275616645813,
#   'Ambulance': 0.6657865047454834,
#   'Firecar': 0.4014665484428406,
#   'Excavator': 0.5399563908576965,
#   'Construction truck': 0.7080659866333008,
#   'Car moving truck': 0.5427878499031067,
#   'Offroad parking': 0.44909045100212097,
#   'Construction car': 0.6482582092285156,
#   'Construction worker': 0.674580991268158},
#  'L2ndFloor-D-2022-02-01_T-03_00_01.jpg': {'Barricade': 0.6169232130050659,
#   'Traffic cone': 0.7714223861694336,
#   'Traffic barrel': 0.6105174422264099,
#   'Scaffold': 0.4536070227622986,
#   'Trailer truck': 0.4464038014411926,
#   'Police car': 0.9800993800163269,
#   'Ambulance': 0.7661502361297607,
#   'Firecar': 0.6063958406448364,
#   'Excavator': 0.3799832761287689,
#   'Construction truck': 0.4560399055480957,
#   'Car moving truck': 0.5151187181472778,
#   'Offroad parking': 0.5090062618255615,
#   'Construction car': 0.5493927001953125,
#   'Construction worker': 0.5650490522384644},
#  'L2ndFloor-D-2022-03-26_T-03_00_01.jpg': {'Barricade': 0.6875135898590088,
#   'Traffic cone': 0.6817705035209656,
#   'Traffic barrel': 0.5989129543304443,
#   'Scaffold': 0.4863726496696472,
#   'Trailer truck': 0.5142474174499512,
#   'Police car': 0.89308100938797,
#   'Ambulance': 0.6668574810028076,
#   'Firecar': 0.5128737092018127,
#   'Excavator': 0.6974290609359741,
#   'Construction truck': 0.7533583641052246,
#   'Car moving truck': 0.6214574575424194,
#   'Offroad parking': 0.4629148542881012,
#   'Construction car': 0.7501133680343628,
#   'Construction worker': 0.8793160915374756},
#  'L2ndFloor-D-2022-03-07_T-18_00_01.jpg': {'Barricade': 0.7458092570304871,
#   'Traffic cone': 0.8404221534729004,
#   'Traffic barrel': 0.7109721302986145,
#   'Scaffold': 0.9466843605041504,
#   'Trailer truck': 0.6872502565383911,
#   'Police car': 0.6680775284767151,
#   'Ambulance': 0.5407770872116089,
#   'Firecar': 0.44205281138420105,
#   'Excavator': 0.38208141922950745,
#   'Construction truck': 0.822713315486908,
#   'Car moving truck': 0.6510091423988342,
#   'Offroad parking': 0.5156445503234863,
#   'Construction car': 0.6533566117286682,
#   'Construction worker': 0.6366426944732666},
#  'L2ndFloor-D-2022-02-03_T-00_30_02.jpg': {'Barricade': 0.6782192587852478,
#   'Traffic cone': 0.7535110116004944,
#   'Traffic barrel': 0.6358570456504822,
#   'Scaffold': 0.46020543575286865,
#   'Trailer truck': 0.48096075654029846,
#   'Police car': 0.9515230059623718,
#   'Ambulance': 0.7092685103416443,
#   'Firecar': 0.6027368903160095,
#   'Excavator': 0.5120560526847839,
#   'Construction truck': 0.6168734431266785,
#   'Car moving truck': 0.6192998886108398,
#   'Offroad parking': 0.49020278453826904,
#   'Construction car': 0.5897486805915833,
#   'Construction worker': 0.573762834072113},
#  'L2ndFloor-D-2022-02-20_T-18_00_01.jpg': {'Barricade': 0.7072122097015381,
#   'Traffic cone': 0.7776538729667664,
#   'Traffic barrel': 0.6756300926208496,
#   'Scaffold': 0.7806662917137146,
#   'Trailer truck': 0.7706019282341003,
#   'Police car': 0.7078520059585571,
#   'Ambulance': 0.6659653186798096,
#   'Firecar': 0.44046443700790405,
#   'Excavator': 0.36470872163772583,
#   'Construction truck': 0.8191311955451965,
#   'Car moving truck': 0.6513668298721313,
#   'Offroad parking': 0.4642321467399597,
#   'Construction car': 0.621802031993866,
#   'Construction worker': 0.7402026057243347},
#  'L2ndFloor-D-2022-03-19_T-18_00_01.jpg': {'Barricade': 0.8166785836219788,
#   'Traffic cone': 0.794704020023346,
#   'Traffic barrel': 0.6955305933952332,
#   'Scaffold': 0.9503085017204285,
#   'Trailer truck': 0.4340057075023651,
#   'Police car': 0.6684194803237915,
#   'Ambulance': 0.5118244290351868,
#   'Firecar': 0.40046462416648865,
#   'Excavator': 0.37685835361480713,
#   'Construction truck': 0.5404812097549438,
#   'Car moving truck': 0.48918119072914124,
#   'Offroad parking': 0.47051116824150085,
#   'Construction car': 0.5881269574165344,
#   'Construction worker': 0.7046352028846741},
#  'L2ndFloor-D-2022-01-10_T-00_00_01.jpg': {'Barricade': 0.6763967871665955,
#   'Traffic cone': 0.8071057796478271,
#   'Traffic barrel': 0.7504050135612488,
#   'Scaffold': 0.5244709253311157,
#   'Trailer truck': 0.49439066648483276,
#   'Police car': 0.8230804800987244,
#   'Ambulance': 0.7456547021865845,
#   'Firecar': 0.7385924458503723,
#   'Excavator': 0.3912014663219452,
#   'Construction truck': 0.5777930021286011,
#   'Car moving truck': 0.5799326300621033,
#   'Offroad parking': 0.48011863231658936,
#   'Construction car': 0.6172995567321777,
#   'Construction worker': 0.6714833378791809},
#  'L2ndFloor-D-2022-02-23_T-22_30_02.jpg': {'Barricade': 0.7463497519493103,
#   'Traffic cone': 0.8627979159355164,
#   'Traffic barrel': 0.7312732934951782,
#   'Scaffold': 0.9187586307525635,
#   'Trailer truck': 0.6859937310218811,
#   'Police car': 0.6530919075012207,
#   'Ambulance': 0.5818905234336853,
#   'Firecar': 0.4955470860004425,
#   'Excavator': 0.427842378616333,
#   'Construction truck': 0.7695721983909607,
#   'Car moving truck': 0.6589195132255554,
#   'Offroad parking': 0.4914510250091553,
#   'Construction car': 0.6441296339035034,
#   'Construction worker': 0.7579503655433655},
#  'L2ndFloor-D-2022-03-12_T-14_00_01.jpg': {'Barricade': 0.8242671489715576,
#   'Traffic cone': 0.7728268504142761,
#   'Traffic barrel': 0.7317166924476624,
#   'Scaffold': 0.911910355091095,
#   'Trailer truck': 0.5740097165107727,
#   'Police car': 0.7127448916435242,
#   'Ambulance': 0.55954509973526,
#   'Firecar': 0.4840211868286133,
#   'Excavator': 0.5159720778465271,
#   'Construction truck': 0.6582075953483582,
#   'Car moving truck': 0.6615672707557678,
#   'Offroad parking': 0.503463089466095,
#   'Construction car': 0.6418381929397583,
#   'Construction worker': 0.7010815739631653},
#  'L2ndFloor-D-2022-02-26_T-03_30_02.jpg': {'Barricade': 0.6126730442047119,
#   'Traffic cone': 0.7347632646560669,
#   'Traffic barrel': 0.5714380145072937,
#   'Scaffold': 0.4856148362159729,
#   'Trailer truck': 0.7689017653465271,
#   'Police car': 0.9979384541511536,
#   'Ambulance': 0.8669089674949646,
#   'Firecar': 0.565249502658844,
#   'Excavator': 0.31685522198677063,
#   'Construction truck': 0.7632037997245789,
#   'Car moving truck': 0.694632351398468,
#   'Offroad parking': 0.5358408093452454,
#   'Construction car': 0.5685626864433289,
#   'Construction worker': 0.5556926727294922},
#  'L2ndFloor-D-2022-02-24_T-00_00_01.jpg': {'Barricade': 0.695582926273346,
#   'Traffic cone': 0.8548714518547058,
#   'Traffic barrel': 0.6674051284790039,
#   'Scaffold': 0.4450460970401764,
#   'Trailer truck': 0.7605159282684326,
#   'Police car': 0.9765289425849915,
#   'Ambulance': 0.7332388162612915,
#   'Firecar': 0.616803765296936,
#   'Excavator': 0.3114911615848541,
#   'Construction truck': 0.7415686249732971,
#   'Car moving truck': 0.6522409915924072,
#   'Offroad parking': 0.4530698359012604,
#   'Construction car': 0.6122193932533264,
#   'Construction worker': 0.5527421832084656},
#  'L2ndFloor-D-2022-04-04_T-14_30_01.jpg': {'Barricade': 0.6260384321212769,
#   'Traffic cone': 0.6824840307235718,
#   'Traffic barrel': 0.5695536136627197,
#   'Scaffold': 0.9655859470367432,
#   'Trailer truck': 0.7190766930580139,
#   'Police car': 0.8268974423408508,
#   'Ambulance': 0.699622392654419,
#   'Firecar': 0.4291105270385742,
#   'Excavator': 0.3407481610774994,
#   'Construction truck': 0.6115681529045105,
#   'Car moving truck': 0.6778714656829834,
#   'Offroad parking': 0.4846540689468384,
#   'Construction car': 0.5572113394737244,
#   'Construction worker': 0.6647399067878723},
#  'L2ndFloor-D-2022-03-25_T-00_30_01.jpg': {'Barricade': 0.7800251245498657,
#   'Traffic cone': 0.8085052371025085,
#   'Traffic barrel': 0.6873898506164551,
#   'Scaffold': 0.6374850869178772,
#   'Trailer truck': 0.5556104779243469,
#   'Police car': 0.723573625087738,
#   'Ambulance': 0.6741591095924377,
#   'Firecar': 0.6062687039375305,
#   'Excavator': 0.831501841545105,
#   'Construction truck': 0.8632124662399292,
#   'Car moving truck': 0.6313350200653076,
#   'Offroad parking': 0.4250924587249756,
#   'Construction car': 0.7905666828155518,
#   'Construction worker': 0.8559646010398865},
#  'L2ndFloor-D-2021-12-30_T-03_30_01.jpg': {'Barricade': 0.7793283462524414,
#   'Traffic cone': 0.8625761270523071,
#   'Traffic barrel': 0.7440187335014343,
#   'Scaffold': 0.48492124676704407,
#   'Trailer truck': 0.4516598582267761,
#   'Police car': 0.9414874315261841,
#   'Ambulance': 0.7392218112945557,
#   'Firecar': 0.6806582808494568,
#   'Excavator': 0.3587995171546936,
#   'Construction truck': 0.4696999490261078,
#   'Car moving truck': 0.5019137859344482,
#   'Offroad parking': 0.4583766460418701,
#   'Construction car': 0.5730488896369934,
#   'Construction worker': 0.6210366487503052},
#  'L2ndFloor-D-2022-02-21_T-18_00_02.jpg': {'Barricade': 0.7040538787841797,
#   'Traffic cone': 0.6115885376930237,
#   'Traffic barrel': 0.5224170088768005,
#   'Scaffold': 0.8892356157302856,
#   'Trailer truck': 0.6307554841041565,
#   'Police car': 0.7046470642089844,
#   'Ambulance': 0.7185138463973999,
#   'Firecar': 0.47532156109809875,
#   'Excavator': 0.39661023020744324,
#   'Construction truck': 0.7829465270042419,
#   'Car moving truck': 0.6453715562820435,
#   'Offroad parking': 0.46138668060302734,
#   'Construction car': 0.6902258396148682,
#   'Construction worker': 0.65155428647995},
#  'L2ndFloor-D-2022-03-06_T-18_00_02.jpg': {'Barricade': 0.8177496790885925,
#   'Traffic cone': 0.8577402830123901,
#   'Traffic barrel': 0.7307177186012268,
#   'Scaffold': 0.9895861744880676,
#   'Trailer truck': 0.7115753293037415,
#   'Police car': 0.7058402299880981,
#   'Ambulance': 0.6310728788375854,
#   'Firecar': 0.4637101888656616,
#   'Excavator': 0.3778475821018219,
#   'Construction truck': 0.8121850490570068,
#   'Car moving truck': 0.6421909928321838,
#   'Offroad parking': 0.5050874948501587,
#   'Construction car': 0.62883460521698,
#   'Construction worker': 0.732234537601471},
#  'L2ndFloor-D-2022-02-04_T-22_00_01.jpg': {'Barricade': 0.8112059831619263,
#   'Traffic cone': 0.8398023247718811,
#   'Traffic barrel': 0.7070507407188416,
#   'Scaffold': 0.5899113416671753,
#   'Trailer truck': 0.5529510974884033,
#   'Police car': 0.7930505275726318,
#   'Ambulance': 0.813197135925293,
#   'Firecar': 0.6785480976104736,
#   'Excavator': 0.39960983395576477,
#   'Construction truck': 0.5729792714118958,
#   'Car moving truck': 0.6108271479606628,
#   'Offroad parking': 0.455556720495224,
#   'Construction car': 0.5630373358726501,
#   'Construction worker': 0.6350444555282593},
#  'L2ndFloor-D-2022-03-23_T-22_00_01.jpg': {'Barricade': 0.7853420376777649,
#   'Traffic cone': 0.8403167128562927,
#   'Traffic barrel': 0.7614647150039673,
#   'Scaffold': 0.9285753965377808,
#   'Trailer truck': 0.44581013917922974,
#   'Police car': 0.7580919861793518,
#   'Ambulance': 0.539169192314148,
#   'Firecar': 0.42739447951316833,
#   'Excavator': 0.34625542163848877,
#   'Construction truck': 0.5251947641372681,
#   'Car moving truck': 0.5423083901405334,
#   'Offroad parking': 0.4792720079421997,
#   'Construction car': 0.5645022392272949,
#   'Construction worker': 0.6883872747421265},
#  'L2ndFloor-D-2022-01-01_T-14_00_01.jpg': {'Barricade': 0.8357343077659607,
#   'Traffic cone': 0.9190243482589722,
#   'Traffic barrel': 0.861519455909729,
#   'Scaffold': 0.6436198949813843,
#   'Trailer truck': 0.44044074416160583,
#   'Police car': 0.6090212464332581,
#   'Ambulance': 0.5492909550666809,
#   'Firecar': 0.40894120931625366,
#   'Excavator': 0.3928825557231903,
#   'Construction truck': 0.5330624580383301,
#   'Car moving truck': 0.5040844678878784,
#   'Offroad parking': 0.4669640362262726,
#   'Construction car': 0.5832017064094543,
#   'Construction worker': 0.6504030227661133},
#  'L2ndFloor-D-2022-02-22_T-22_30_01.jpg': {'Barricade': 0.7429841160774231,
#   'Traffic cone': 0.8706819415092468,
#   'Traffic barrel': 0.7164259552955627,
#   'Scaffold': 0.6525260210037231,
#   'Trailer truck': 0.7522837519645691,
#   'Police car': 0.827178418636322,
#   'Ambulance': 0.8032793998718262,
#   'Firecar': 0.5770575404167175,
#   'Excavator': 0.38547250628471375,
#   'Construction truck': 0.7691875696182251,
#   'Car moving truck': 0.6433213353157043,
#   'Offroad parking': 0.47740882635116577,
#   'Construction car': 0.6585617661476135,
#   'Construction worker': 0.7110429406166077},
#  'L2ndFloor-D-2022-04-08_T-03_00_01.jpg': {'Barricade': 0.6673181653022766,
#   'Traffic cone': 0.6064398288726807,
#   'Traffic barrel': 0.5345022678375244,
#   'Scaffold': 0.4674074351787567,
#   'Trailer truck': 0.4794531464576721,
#   'Police car': 0.7818278670310974,
#   'Ambulance': 0.6093296408653259,
#   'Firecar': 0.5941223502159119,
#   'Excavator': 0.44322577118873596,
#   'Construction truck': 0.6110599040985107,
#   'Car moving truck': 0.5137612223625183,
#   'Offroad parking': 0.5121190547943115,
#   'Construction car': 0.5900558233261108,
#   'Construction worker': 0.5519338846206665},
#  'L2ndFloor-D-2022-04-09_T-22_30_01.jpg': {'Barricade': 0.8035634756088257,
#   'Traffic cone': 0.7372109889984131,
#   'Traffic barrel': 0.7292879223823547,
#   'Scaffold': 0.96869295835495,
#   'Trailer truck': 0.44978758692741394,
#   'Police car': 0.6730400323867798,
#   'Ambulance': 0.5274233222007751,
#   'Firecar': 0.4233686625957489,
#   'Excavator': 0.35958245396614075,
#   'Construction truck': 0.52249675989151,
#   'Car moving truck': 0.5163119435310364,
#   'Offroad parking': 0.45422253012657166,
#   'Construction car': 0.5857336521148682,
#   'Construction worker': 0.7364100813865662},
#  'L2ndFloor-D-2022-04-01_T-14_00_02.jpg': {'Barricade': 0.6035642027854919,
#   'Traffic cone': 0.7271715402603149,
#   'Traffic barrel': 0.5902595520019531,
#   'Scaffold': 0.9325618147850037,
#   'Trailer truck': 0.8021466135978699,
#   'Police car': 0.7775363326072693,
#   'Ambulance': 0.5777445435523987,
#   'Firecar': 0.4031926095485687,
#   'Excavator': 0.40458348393440247,
#   'Construction truck': 0.6389161944389343,
#   'Car moving truck': 0.6664931774139404,
#   'Offroad parking': 0.4813460409641266,
#   'Construction car': 0.6461474299430847,
#   'Construction worker': 0.6623317003250122},
#  'L2ndFloor-D-2022-03-25_T-18_00_01.jpg': {'Barricade': 0.8144106268882751,
#   'Traffic cone': 0.7778235673904419,
#   'Traffic barrel': 0.7209040522575378,
#   'Scaffold': 0.9655655026435852,
#   'Trailer truck': 0.4847765862941742,
#   'Police car': 0.631028413772583,
#   'Ambulance': 0.6128902435302734,
#   'Firecar': 0.48689472675323486,
#   'Excavator': 0.6889861822128296,
#   'Construction truck': 0.7288542985916138,
#   'Car moving truck': 0.6578664779663086,
#   'Offroad parking': 0.42967110872268677,
#   'Construction car': 0.7409975528717041,
#   'Construction worker': 0.8787069916725159},
#  'L2ndFloor-D-2022-02-23_T-03_00_01.jpg': {'Barricade': 0.7287625670433044,
#   'Traffic cone': 0.8664574027061462,
#   'Traffic barrel': 0.6905428767204285,
#   'Scaffold': 0.4572092294692993,
#   'Trailer truck': 0.7839241623878479,
#   'Police car': 0.886212944984436,
#   'Ambulance': 0.725396454334259,
#   'Firecar': 0.7240197062492371,
#   'Excavator': 0.33299264311790466,
#   'Construction truck': 0.8499581217765808,
#   'Car moving truck': 0.6338174343109131,
#   'Offroad parking': 0.54863440990448,
#   'Construction car': 0.6239122152328491,
#   'Construction worker': 0.5284655094146729},
#  'L2ndFloor-D-2022-03-04_T-03_00_01.jpg': {'Barricade': 0.7780264019966125,
#   'Traffic cone': 0.8478385806083679,
#   'Traffic barrel': 0.7124550938606262,
#   'Scaffold': 0.4868091642856598,
#   'Trailer truck': 0.7901824712753296,
#   'Police car': 0.8430933952331543,
#   'Ambulance': 0.7267522811889648,
#   'Firecar': 0.6007120013237,
#   'Excavator': 0.36397621035575867,
#   'Construction truck': 0.8538960218429565,
#   'Car moving truck': 0.6804046034812927,
#   'Offroad parking': 0.48911523818969727,
#   'Construction car': 0.6484830379486084,
#   'Construction worker': 0.6099273562431335},
#  'L2ndFloor-D-2022-02-24_T-18_30_01.jpg': {'Barricade': 0.7736120223999023,
#   'Traffic cone': 0.7483909726142883,
#   'Traffic barrel': 0.6026757955551147,
#   'Scaffold': 0.957894504070282,
#   'Trailer truck': 0.8738475441932678,
#   'Police car': 0.7279078364372253,
#   'Ambulance': 0.7490971088409424,
#   'Firecar': 0.4465044140815735,
#   'Excavator': 0.35637134313583374,
#   'Construction truck': 0.8402078151702881,
#   'Car moving truck': 0.719761848449707,
#   'Offroad parking': 0.4834233820438385,
#   'Construction car': 0.6404333114624023,
#   'Construction worker': 0.7105580568313599},
#  'L2ndFloor-D-2022-03-22_T-03_30_01.jpg': {'Barricade': 0.761298656463623,
#   'Traffic cone': 0.8549494743347168,
#   'Traffic barrel': 0.7021929621696472,
#   'Scaffold': 0.4556567072868347,
#   'Trailer truck': 0.5099667906761169,
#   'Police car': 0.9858371019363403,
#   'Ambulance': 0.7934955954551697,
#   'Firecar': 0.5291610956192017,
#   'Excavator': 0.3431250751018524,
#   'Construction truck': 0.4860905110836029,
#   'Car moving truck': 0.5142626762390137,
#   'Offroad parking': 0.559194028377533,
#   'Construction car': 0.5244070291519165,
#   'Construction worker': 0.6068127155303955},
#  'L2ndFloor-D-2022-02-05_T-03_30_01.jpg': {'Barricade': 0.7488634586334229,
#   'Traffic cone': 0.7982367873191833,
#   'Traffic barrel': 0.704160749912262,
#   'Scaffold': 0.48524123430252075,
#   'Trailer truck': 0.46755072474479675,
#   'Police car': 0.916579008102417,
#   'Ambulance': 0.7513923645019531,
#   'Firecar': 0.7316993474960327,
#   'Excavator': 0.3284631669521332,
#   'Construction truck': 0.47689110040664673,
#   'Car moving truck': 0.48837772011756897,
#   'Offroad parking': 0.4659261107444763,
#   'Construction car': 0.5297868251800537,
#   'Construction worker': 0.6117470264434814},
#  'L2ndFloor-D-2022-02-17_T-14_00_01.jpg': {'Barricade': 0.7424138784408569,
#   'Traffic cone': 0.7088947296142578,
#   'Traffic barrel': 0.6558634638786316,
#   'Scaffold': 0.9900056719779968,
#   'Trailer truck': 0.6857733130455017,
#   'Police car': 0.7781633734703064,
#   'Ambulance': 0.7328543663024902,
#   'Firecar': 0.49953681230545044,
#   'Excavator': 0.38944169878959656,
#   'Construction truck': 0.6944678425788879,
#   'Car moving truck': 0.7086920738220215,
#   'Offroad parking': 0.5109726190567017,
#   'Construction car': 0.6623064875602722,
#   'Construction worker': 0.7045975923538208},
#  'L2ndFloor-D-2022-03-30_T-14_00_01.jpg': {'Barricade': 0.7240942120552063,
#   'Traffic cone': 0.8058150410652161,
#   'Traffic barrel': 0.5917486548423767,
#   'Scaffold': 0.9317076802253723,
#   'Trailer truck': 0.7243162393569946,
#   'Police car': 0.9871013164520264,
#   'Ambulance': 0.7271770238876343,
#   'Firecar': 0.6256096959114075,
#   'Excavator': 0.6155815124511719,
#   'Construction truck': 0.896772563457489,
#   'Car moving truck': 0.7711677551269531,
#   'Offroad parking': 0.45531415939331055,
#   'Construction car': 0.761600136756897,
#   'Construction worker': 0.7960813045501709},
#  'L2ndFloor-D-2021-12-31_T-22_00_01.jpg': {'Barricade': 0.7899841666221619,
#   'Traffic cone': 0.8592020869255066,
#   'Traffic barrel': 0.7713497281074524,
#   'Scaffold': 0.5103598237037659,
#   'Trailer truck': 0.49161189794540405,
#   'Police car': 0.9338918328285217,
#   'Ambulance': 0.7129244208335876,
#   'Firecar': 0.5199339985847473,
#   'Excavator': 0.337184876203537,
#   'Construction truck': 0.5019264221191406,
#   'Car moving truck': 0.5576895475387573,
#   'Offroad parking': 0.4479190409183502,
#   'Construction car': 0.5378017425537109,
#   'Construction worker': 0.665657103061676},
#  'L2ndFloor-D-2022-01-10_T-18_30_01.jpg': {'Barricade': 0.813520610332489,
#   'Traffic cone': 0.8911395072937012,
#   'Traffic barrel': 0.7203093767166138,
#   'Scaffold': 0.6208764314651489,
#   'Trailer truck': 0.6742038726806641,
#   'Police car': 0.6706607937812805,
#   'Ambulance': 0.798811137676239,
#   'Firecar': 0.4317116439342499,
#   'Excavator': 0.36535540223121643,
#   'Construction truck': 0.7197558879852295,
#   'Car moving truck': 0.6532238125801086,
#   'Offroad parking': 0.4335032105445862,
#   'Construction car': 0.6723626852035522,
#   'Construction worker': 0.6627597212791443},
#  'L2ndFloor-D-2022-03-07_T-00_30_01.jpg': {'Barricade': 0.7243368029594421,
#   'Traffic cone': 0.8596676588058472,
#   'Traffic barrel': 0.7009510397911072,
#   'Scaffold': 0.43946757912635803,
#   'Trailer truck': 0.772956371307373,
#   'Police car': 0.8462972044944763,
#   'Ambulance': 0.7710258960723877,
#   'Firecar': 0.5902324318885803,
#   'Excavator': 0.3233841061592102,
#   'Construction truck': 0.743668794631958,
#   'Car moving truck': 0.6317940950393677,
#   'Offroad parking': 0.4975869357585907,
#   'Construction car': 0.5933097004890442,
#   'Construction worker': 0.558804988861084},
#  'L2ndFloor-D-2022-03-19_T-00_30_01.jpg': {'Barricade': 0.7039223313331604,
#   'Traffic cone': 0.804684042930603,
#   'Traffic barrel': 0.6762402653694153,
#   'Scaffold': 0.4334377348423004,
#   'Trailer truck': 0.5055504441261292,
#   'Police car': 0.9493828415870667,
#   'Ambulance': 0.77486252784729,
#   'Firecar': 0.5912910103797913,
#   'Excavator': 0.31872278451919556,
#   'Construction truck': 0.4572075307369232,
#   'Car moving truck': 0.5095052123069763,
#   'Offroad parking': 0.5347071290016174,
#   'Construction car': 0.5406475067138672,
#   'Construction worker': 0.5621679425239563},
#  'L2ndFloor-D-2022-02-20_T-00_30_01.jpg': {'Barricade': 0.7790457606315613,
#   'Traffic cone': 0.8930896520614624,
#   'Traffic barrel': 0.8273382782936096,
#   'Scaffold': 0.509608805179596,
#   'Trailer truck': 0.7519060373306274,
#   'Police car': 0.8813750743865967,
#   'Ambulance': 0.808071494102478,
#   'Firecar': 0.5822206139564514,
#   'Excavator': 0.3448232114315033,
#   'Construction truck': 0.8381842970848083,
#   'Car moving truck': 0.6714194416999817,
#   'Offroad parking': 0.48379623889923096,
#   'Construction car': 0.6385600566864014,
#   'Construction worker': 0.5777275562286377},
#  'L2ndFloor-D-2022-02-06_T-00_00_01.jpg': {'Barricade': 0.7336870431900024,
#   'Traffic cone': 0.628791868686676,
#   'Traffic barrel': 0.5849018692970276,
#   'Scaffold': 0.48651397228240967,
#   'Trailer truck': 0.6388324499130249,
#   'Police car': 0.992771327495575,
#   'Ambulance': 0.7048344612121582,
#   'Firecar': 0.5512473583221436,
#   'Excavator': 0.6889315247535706,
#   'Construction truck': 0.8997336030006409,
#   'Car moving truck': 0.673165500164032,
#   'Offroad parking': 0.4703780710697174,
#   'Construction car': 0.7738897204399109,
#   'Construction worker': 0.6676708459854126},
#  'L2ndFloor-D-2022-03-21_T-00_00_01.jpg': {'Barricade': 0.7414227724075317,
#   'Traffic cone': 0.8449422717094421,
#   'Traffic barrel': 0.7157045602798462,
#   'Scaffold': 0.4509335160255432,
#   'Trailer truck': 0.46318718791007996,
#   'Police car': 0.8772996068000793,
#   'Ambulance': 0.691047728061676,
#   'Firecar': 0.5437250733375549,
#   'Excavator': 0.32676899433135986,
#   'Construction truck': 0.4827784597873688,
#   'Car moving truck': 0.5380010604858398,
#   'Offroad parking': 0.5132163166999817,
#   'Construction car': 0.5528020262718201,
#   'Construction worker': 0.593874990940094},
#  'L2ndFloor-D-2022-02-18_T-00_00_01.jpg': {'Barricade': 0.7348755598068237,
#   'Traffic cone': 0.8199765086174011,
#   'Traffic barrel': 0.6911115646362305,
#   'Scaffold': 0.42449212074279785,
#   'Trailer truck': 0.7944076061248779,
#   'Police car': 0.859257161617279,
#   'Ambulance': 0.746489942073822,
#   'Firecar': 0.6420636773109436,
#   'Excavator': 0.4799317419528961,
#   'Construction truck': 0.8493931293487549,
#   'Car moving truck': 0.6531256437301636,
#   'Offroad parking': 0.49273550510406494,
#   'Construction car': 0.676149308681488,
#   'Construction worker': 0.6795687079429626},
#  'L2ndFloor-D-2022-02-04_T-03_30_02.jpg': {'Barricade': 0.5616981983184814,
#   'Traffic cone': 0.5472667813301086,
#   'Traffic barrel': 0.4867226183414459,
#   'Scaffold': 0.44588810205459595,
#   'Trailer truck': 0.4634183943271637,
#   'Police car': 0.9415941834449768,
#   'Ambulance': 0.7135496139526367,
#   'Firecar': 0.6261743307113647,
#   'Excavator': 0.3872402012348175,
#   'Construction truck': 0.44238001108169556,
#   'Car moving truck': 0.5322353839874268,
#   'Offroad parking': 0.510241687297821,
#   'Construction car': 0.4867135286331177,
#   'Construction worker': 0.5471004843711853},
#  'L2ndFloor-D-2022-01-09_T-03_00_01.jpg': {'Barricade': 0.7674440145492554,
#   'Traffic cone': 0.8598877191543579,
#   'Traffic barrel': 0.8120154142379761,
#   'Scaffold': 0.5078353881835938,
#   'Trailer truck': 0.5445154309272766,
#   'Police car': 0.89197838306427,
#   'Ambulance': 0.7475952506065369,
#   'Firecar': 0.5940622687339783,
#   'Excavator': 0.36763420701026917,
#   'Construction truck': 0.5234079360961914,
#   'Car moving truck': 0.6609540581703186,
#   'Offroad parking': 0.4982394278049469,
#   'Construction car': 0.608279824256897,
#   'Construction worker': 0.5564234852790833},
#  'L2ndFloor-D-2021-12-26_T-14_30_01.jpg': {'Barricade': 0.7642689943313599,
#   'Traffic cone': 0.7886028289794922,
#   'Traffic barrel': 0.708787202835083,
#   'Scaffold': 0.6061725616455078,
#   'Trailer truck': 0.4314822256565094,
#   'Police car': 0.9474706649780273,
#   'Ambulance': 0.5963882803916931,
#   'Firecar': 0.4674752652645111,
#   'Excavator': 0.43763336539268494,
#   'Construction truck': 0.47275009751319885,
#   'Car moving truck': 0.5735899209976196,
#   'Offroad parking': 0.46159568428993225,
#   'Construction car': 0.5793997049331665,
#   'Construction worker': 0.6896621584892273},
#  'L2ndFloor-D-2021-12-30_T-22_00_02.jpg': {'Barricade': 0.7996708750724792,
#   'Traffic cone': 0.8295338749885559,
#   'Traffic barrel': 0.7151216268539429,
#   'Scaffold': 0.5356501936912537,
#   'Trailer truck': 0.4612331688404083,
#   'Police car': 0.8841999173164368,
#   'Ambulance': 0.7371779680252075,
#   'Firecar': 0.5512332916259766,
#   'Excavator': 0.3409094512462616,
#   'Construction truck': 0.4743388295173645,
#   'Car moving truck': 0.49459603428840637,
#   'Offroad parking': 0.4643714427947998,
#   'Construction car': 0.553935706615448,
#   'Construction worker': 0.632337749004364},
#  'L2ndFloor-D-2022-03-27_T-22_30_01.jpg': {'Barricade': 0.8060222268104553,
#   'Traffic cone': 0.841467559337616,
#   'Traffic barrel': 0.7206078767776489,
#   'Scaffold': 0.9191086292266846,
#   'Trailer truck': 0.4733114242553711,
#   'Police car': 0.7093819379806519,
#   'Ambulance': 0.5388622283935547,
#   'Firecar': 0.44767406582832336,
#   'Excavator': 0.37821951508522034,
#   'Construction truck': 0.5313406586647034,
#   'Car moving truck': 0.5541933178901672,
#   'Offroad parking': 0.4032098352909088,
#   'Construction car': 0.6007598638534546,
#   'Construction worker': 0.7091400027275085},
#  'L2ndFloor-D-2022-02-26_T-22_00_01.jpg': {'Barricade': 0.7584054470062256,
#   'Traffic cone': 0.8541891574859619,
#   'Traffic barrel': 0.7314745783805847,
#   'Scaffold': 0.9765871167182922,
#   'Trailer truck': 0.7840900421142578,
#   'Police car': 0.6762046217918396,
#   'Ambulance': 0.609636127948761,
#   'Firecar': 0.45360469818115234,
#   'Excavator': 0.39865997433662415,
#   'Construction truck': 0.8428337574005127,
#   'Car moving truck': 0.679357647895813,
#   'Offroad parking': 0.4816366732120514,
#   'Construction car': 0.6641134023666382,
#   'Construction worker': 0.6759448647499084},
#  'L2ndFloor-D-2022-03-01_T-22_00_01.jpg': {'Barricade': 0.6382567882537842,
#   'Traffic cone': 0.796850323677063,
#   'Traffic barrel': 0.6687775254249573,
#   'Scaffold': 0.9716591238975525,
#   'Trailer truck': 0.6323548555374146,
#   'Police car': 0.6937560439109802,
#   'Ambulance': 0.7021611332893372,
#   'Firecar': 0.5739555358886719,
#   'Excavator': 0.4361257255077362,
#   'Construction truck': 0.6434561610221863,
#   'Car moving truck': 0.6056798696517944,
#   'Offroad parking': 0.4643607437610626,
#   'Construction car': 0.6018593311309814,
#   'Construction worker': 0.6763622164726257},
#  'L2ndFloor-D-2022-01-06_T-14_00_01.jpg': {'Barricade': 0.8070932626724243,
#   'Traffic cone': 0.8360224962234497,
#   'Traffic barrel': 0.8254477977752686,
#   'Scaffold': 0.5272574424743652,
#   'Trailer truck': 0.5851207971572876,
#   'Police car': 0.7381359934806824,
#   'Ambulance': 0.6560223698616028,
#   'Firecar': 0.4501047730445862,
#   'Excavator': 0.36803653836250305,
#   'Construction truck': 0.5776411890983582,
#   'Car moving truck': 0.5882432460784912,
#   'Offroad parking': 0.4759027361869812,
#   'Construction car': 0.5740891695022583,
#   'Construction worker': 0.5625215172767639},
#  'L2ndFloor-D-2022-02-03_T-22_00_01.jpg': {'Barricade': 0.7249628305435181,
#   'Traffic cone': 0.8318347930908203,
#   'Traffic barrel': 0.6917838454246521,
#   'Scaffold': 0.5551641583442688,
#   'Trailer truck': 0.5256142616271973,
#   'Police car': 0.6971868872642517,
#   'Ambulance': 0.6285049915313721,
#   'Firecar': 0.5136587023735046,
#   'Excavator': 0.398915559053421,
#   'Construction truck': 0.5616717338562012,
#   'Car moving truck': 0.6015493273735046,
#   'Offroad parking': 0.4697818160057068,
#   'Construction car': 0.540250301361084,
#   'Construction worker': 0.6087813973426819},
#  'L2ndFloor-D-2022-04-08_T-18_30_01.jpg': {'Barricade': 0.7895527482032776,
#   'Traffic cone': 0.7514356374740601,
#   'Traffic barrel': 0.6659078001976013,
#   'Scaffold': 0.852774441242218,
#   'Trailer truck': 0.5079585313796997,
#   'Police car': 0.7879133224487305,
#   'Ambulance': 0.6540167927742004,
#   'Firecar': 0.5010948777198792,
#   'Excavator': 0.47124776244163513,
#   'Construction truck': 0.6518296003341675,
#   'Car moving truck': 0.5411073565483093,
#   'Offroad parking': 0.42234134674072266,
#   'Construction car': 0.6703380942344666,
#   'Construction worker': 0.706494927406311},
#  'L2ndFloor-D-2021-12-25_T-14_00_01.jpg': {'Barricade': 0.8107420206069946,
#   'Traffic cone': 0.8954757452011108,
#   'Traffic barrel': 0.770505964756012,
#   'Scaffold': 0.6315906047821045,
#   'Trailer truck': 0.4422094523906708,
#   'Police car': 0.6623722314834595,
#   'Ambulance': 0.5240402817726135,
#   'Firecar': 0.42597606778144836,
#   'Excavator': 0.39000600576400757,
#   'Construction truck': 0.5081114172935486,
#   'Car moving truck': 0.5217975974082947,
#   'Offroad parking': 0.48905980587005615,
#   'Construction car': 0.6015304327011108,
#   'Construction worker': 0.6502652764320374},
#  'L2ndFloor-D-2022-01-10_T-22_30_02.jpg': {'Barricade': 0.7940413951873779,
#   'Traffic cone': 0.8777783513069153,
#   'Traffic barrel': 0.75906902551651,
#   'Scaffold': 0.49672916531562805,
#   'Trailer truck': 0.49495673179626465,
#   'Police car': 0.9332368969917297,
#   'Ambulance': 0.7501457929611206,
#   'Firecar': 0.5822550058364868,
#   'Excavator': 0.34669676423072815,
#   'Construction truck': 0.5072870254516602,
#   'Car moving truck': 0.5518927574157715,
#   'Offroad parking': 0.45075228810310364,
#   'Construction car': 0.6027733683586121,
#   'Construction worker': 0.6653602719306946},
#  'L2ndFloor-D-2022-03-14_T-14_00_02.jpg': {'Barricade': 0.6793723106384277,
#   'Traffic cone': 0.8407793045043945,
#   'Traffic barrel': 0.7594714760780334,
#   'Scaffold': 0.9066449403762817,
#   'Trailer truck': 0.79647296667099,
#   'Police car': 0.695654034614563,
#   'Ambulance': 0.701109766960144,
#   'Firecar': 0.5603296160697937,
#   'Excavator': 0.3863750696182251,
#   'Construction truck': 0.8098072409629822,
#   'Car moving truck': 0.7299509644508362,
#   'Offroad parking': 0.5566144585609436,
#   'Construction car': 0.6586518287658691,
#   'Construction worker': 0.7598774433135986},
#  'L2ndFloor-D-2022-01-20_T-14_30_01.jpg': {'Barricade': 0.7261531352996826,
#   'Traffic cone': 0.9984685778617859,
#   'Traffic barrel': 0.849356472492218,
#   'Scaffold': 0.5206418037414551,
#   'Trailer truck': 0.6568796038627625,
#   'Police car': 0.925426185131073,
#   'Ambulance': 0.7671269178390503,
#   'Firecar': 0.5118211507797241,
#   'Excavator': 0.8528399467468262,
#   'Construction truck': 0.8987565636634827,
#   'Car moving truck': 0.6847125291824341,
#   'Offroad parking': 0.5142936706542969,
#   'Construction car': 0.7989567518234253,
#   'Construction worker': 0.7671916484832764},
#  'L2ndFloor-D-2022-03-02_T-22_30_01.jpg': {'Barricade': 0.6405824422836304,
#   'Traffic cone': 0.7733620405197144,
#   'Traffic barrel': 0.661813497543335,
#   'Scaffold': 0.9232514500617981,
#   'Trailer truck': 0.7469033598899841,
#   'Police car': 0.7879748344421387,
#   'Ambulance': 0.6159986257553101,
#   'Firecar': 0.48812171816825867,
#   'Excavator': 0.3918531835079193,
#   'Construction truck': 0.7413612604141235,
#   'Car moving truck': 0.699341893196106,
#   'Offroad parking': 0.46680811047554016,
#   'Construction car': 0.5985914468765259,
#   'Construction worker': 0.6932794451713562},
#  'L2ndFloor-D-2022-03-04_T-00_00_01.jpg': {'Barricade': 0.7632171511650085,
#   'Traffic cone': 0.8186309337615967,
#   'Traffic barrel': 0.7507802248001099,
#   'Scaffold': 0.46497178077697754,
#   'Trailer truck': 0.8067792057991028,
#   'Police car': 0.8196150064468384,
#   'Ambulance': 0.7035387754440308,
#   'Firecar': 0.5587604641914368,
#   'Excavator': 0.3806132674217224,
#   'Construction truck': 0.8462746739387512,
#   'Car moving truck': 0.6857272982597351,
#   'Offroad parking': 0.49350786209106445,
#   'Construction car': 0.6847138404846191,
#   'Construction worker': 0.6068044304847717},
#  'L2ndFloor-D-2022-02-23_T-00_00_01.jpg': {'Barricade': 0.6581514477729797,
#   'Traffic cone': 0.7531684637069702,
#   'Traffic barrel': 0.6257402896881104,
#   'Scaffold': 0.46140414476394653,
#   'Trailer truck': 0.6714312434196472,
#   'Police car': 0.81541508436203,
#   'Ambulance': 0.9788436889648438,
#   'Firecar': 0.7437347173690796,
#   'Excavator': 0.35048460960388184,
#   'Construction truck': 0.7570915222167969,
#   'Car moving truck': 0.6161114573478699,
#   'Offroad parking': 0.5562731027603149,
#   'Construction car': 0.6177815198898315,
#   'Construction worker': 0.6751723289489746},
#  'L2ndFloor-D-2022-03-27_T-18_30_02.jpg': {'Barricade': 0.8128291368484497,
#   'Traffic cone': 0.8862810134887695,
#   'Traffic barrel': 0.7661081552505493,
#   'Scaffold': 0.9177777767181396,
#   'Trailer truck': 0.4660932421684265,
#   'Police car': 0.6450799703598022,
#   'Ambulance': 0.5433210730552673,
#   'Firecar': 0.45434272289276123,
#   'Excavator': 0.4120124578475952,
#   'Construction truck': 0.5656412839889526,
#   'Car moving truck': 0.5159570574760437,
#   'Offroad parking': 0.3991011381149292,
#   'Construction car': 0.5955191254615784,
#   'Construction worker': 0.6628837585449219},
#  'L2ndFloor-D-2021-12-30_T-18_00_01.jpg': {'Barricade': 0.8344728946685791,
#   'Traffic cone': 0.8586366772651672,
#   'Traffic barrel': 0.8163394927978516,
#   'Scaffold': 0.6565840244293213,
#   'Trailer truck': 0.48457270860671997,
#   'Police car': 0.6026919484138489,
#   'Ambulance': 0.5470387935638428,
#   'Firecar': 0.4656662046909332,
#   'Excavator': 0.3905581533908844,
#   'Construction truck': 0.5617070198059082,
#   'Car moving truck': 0.587439239025116,
#   'Offroad parking': 0.48221156001091003,
#   'Construction car': 0.6346345543861389,
#   'Construction worker': 0.5853481292724609},
#  'L2ndFloor-D-2021-12-29_T-03_30_01.jpg': {'Barricade': 0.8050127625465393,
#   'Traffic cone': 0.8986417055130005,
#   'Traffic barrel': 0.7329723834991455,
#   'Scaffold': 0.537099301815033,
#   'Trailer truck': 0.4514428377151489,
#   'Police car': 0.8453776240348816,
#   'Ambulance': 0.7185447812080383,
#   'Firecar': 0.5370897054672241,
#   'Excavator': 0.32174447178840637,
#   'Construction truck': 0.44528841972351074,
#   'Car moving truck': 0.48096683621406555,
#   'Offroad parking': 0.47803837060928345,
#   'Construction car': 0.5179318189620972,
#   'Construction worker': 0.6101943850517273},
#  'L2ndFloor-D-2022-02-05_T-00_30_01.jpg': {'Barricade': 0.7308106422424316,
#   'Traffic cone': 0.8002952337265015,
#   'Traffic barrel': 0.672020673751831,
#   'Scaffold': 0.4872462749481201,
#   'Trailer truck': 0.4626355767250061,
#   'Police car': 0.8662577867507935,
#   'Ambulance': 0.7524798512458801,
#   'Firecar': 0.5727187991142273,
#   'Excavator': 0.35209158062934875,
#   'Construction truck': 0.5193929076194763,
#   'Car moving truck': 0.4901493489742279,
#   'Offroad parking': 0.5283136367797852,
#   'Construction car': 0.5316692590713501,
#   'Construction worker': 0.5835763216018677},
#  'L2ndFloor-D-2022-03-22_T-00_30_01.jpg': {'Barricade': 0.7745253443717957,
#   'Traffic cone': 0.8665222525596619,
#   'Traffic barrel': 0.7463863492012024,
#   'Scaffold': 0.4351423382759094,
#   'Trailer truck': 0.5005632042884827,
#   'Police car': 0.8949023485183716,
#   'Ambulance': 0.6691766977310181,
#   'Firecar': 0.5376070737838745,
#   'Excavator': 0.33135461807250977,
#   'Construction truck': 0.49983543157577515,
#   'Car moving truck': 0.5518487095832825,
#   'Offroad parking': 0.47026628255844116,
#   'Construction car': 0.5249265432357788,
#   'Construction worker': 0.5967473983764648},
#  'L2ndFloor-D-2022-03-20_T-03_00_02.jpg': {'Barricade': 0.6300652623176575,
#   'Traffic cone': 0.8023519515991211,
#   'Traffic barrel': 0.6486856937408447,
#   'Scaffold': 0.44377702474594116,
#   'Trailer truck': 0.4603232145309448,
#   'Police car': 0.8603237271308899,
#   'Ambulance': 0.7287542819976807,
#   'Firecar': 0.6324952840805054,
#   'Excavator': 0.3225512206554413,
#   'Construction truck': 0.5079933404922485,
#   'Car moving truck': 0.530529260635376,
#   'Offroad parking': 0.5428221225738525,
#   'Construction car': 0.5118100643157959,
#   'Construction worker': 0.5431634187698364},
#  'L2ndFloor-D-2022-02-19_T-03_00_02.jpg': {'Barricade': 0.7772942781448364,
#   'Traffic cone': 0.8479079604148865,
#   'Traffic barrel': 0.7275482416152954,
#   'Scaffold': 0.4493292570114136,
#   'Trailer truck': 0.7971092462539673,
#   'Police car': 0.8892605304718018,
#   'Ambulance': 0.7281995415687561,
#   'Firecar': 0.5924400091171265,
#   'Excavator': 0.3400483727455139,
#   'Construction truck': 0.8470433354377747,
#   'Car moving truck': 0.664963960647583,
#   'Offroad parking': 0.499428927898407,
#   'Construction car': 0.6272644400596619,
#   'Construction worker': 0.5658919811248779},
#  'L2ndFloor-D-2022-01-07_T-14_00_02.jpg': {'Barricade': 0.7200376987457275,
#   'Traffic cone': 0.727155864238739,
#   'Traffic barrel': 0.6390244960784912,
#   'Scaffold': 0.782145082950592,
#   'Trailer truck': 0.5833880305290222,
#   'Police car': 0.6597183346748352,
#   'Ambulance': 0.688980758190155,
#   'Firecar': 0.5514397621154785,
#   'Excavator': 0.5616965889930725,
#   'Construction truck': 0.650314450263977,
#   'Car moving truck': 0.6776536107063293,
#   'Offroad parking': 0.5212646722793579,
#   'Construction car': 0.6153607964515686,
#   'Construction worker': 0.7534850835800171},
#  'L2ndFloor-D-2022-04-09_T-18_30_02.jpg': {'Barricade': 0.7823038101196289,
#   'Traffic cone': 0.7070337533950806,
#   'Traffic barrel': 0.6671102643013,
#   'Scaffold': 0.9669846296310425,
#   'Trailer truck': 0.46884265542030334,
#   'Police car': 0.8051108717918396,
#   'Ambulance': 0.6837802529335022,
#   'Firecar': 0.46622079610824585,
#   'Excavator': 0.3333742022514343,
#   'Construction truck': 0.4909589886665344,
#   'Car moving truck': 0.5536829829216003,
#   'Offroad parking': 0.46946778893470764,
#   'Construction car': 0.5619248747825623,
#   'Construction worker': 0.6772786378860474},
#  'L2ndFloor-D-2022-02-14_T-14_30_01.jpg': {'Barricade': 0.8138355016708374,
#   'Traffic cone': 0.9510521292686462,
#   'Traffic barrel': 0.8985915184020996,
#   'Scaffold': 0.9666146039962769,
#   'Trailer truck': 0.6516745686531067,
#   'Police car': 0.6284740567207336,
#   'Ambulance': 0.5096673369407654,
#   'Firecar': 0.42172011733055115,
#   'Excavator': 0.5162866115570068,
#   'Construction truck': 0.8805485367774963,
#   'Car moving truck': 0.7308676242828369,
#   'Offroad parking': 0.5010669827461243,
#   'Construction car': 0.7924777865409851,
#   'Construction worker': 0.927452027797699},
#  'L2ndFloor-D-2022-01-29_T-22_00_01.jpg': {'Barricade': 0.7223957180976868,
#   'Traffic cone': 0.8658475279808044,
#   'Traffic barrel': 0.75105220079422,
#   'Scaffold': 0.5367264151573181,
#   'Trailer truck': 0.5215821266174316,
#   'Police car': 0.5317787528038025,
#   'Ambulance': 0.5253066420555115,
#   'Firecar': 0.4235055446624756,
#   'Excavator': 0.5327447652816772,
#   'Construction truck': 0.5659716725349426,
#   'Car moving truck': 0.5512503981590271,
#   'Offroad parking': 0.5140540599822998,
#   'Construction car': 0.672875702381134,
#   'Construction worker': 0.7423757314682007},
#  'L2ndFloor-D-2022-03-26_T-18_30_01.jpg': {'Barricade': 0.8161455392837524,
#   'Traffic cone': 0.8405080437660217,
#   'Traffic barrel': 0.7572592496871948,
#   'Scaffold': 0.9914790987968445,
#   'Trailer truck': 0.4625133275985718,
#   'Police car': 0.7909063100814819,
#   'Ambulance': 0.5662373304367065,
#   'Firecar': 0.4635288715362549,
#   'Excavator': 0.7809451222419739,
#   'Construction truck': 0.7447311282157898,
#   'Car moving truck': 0.5270218849182129,
#   'Offroad parking': 0.45060887932777405,
#   'Construction car': 0.7396386861801147,
#   'Construction worker': 0.823638379573822},
#  'L2ndFloor-D-2022-04-02_T-14_30_02.jpg': {'Barricade': 0.7881718873977661,
#   'Traffic cone': 0.7667237520217896,
#   'Traffic barrel': 0.7098486423492432,
#   'Scaffold': 0.9253696203231812,
#   'Trailer truck': 0.4431895315647125,
#   'Police car': 0.6179871559143066,
#   'Ambulance': 0.5375434756278992,
#   'Firecar': 0.4213367700576782,
#   'Excavator': 0.358191579580307,
#   'Construction truck': 0.510139524936676,
#   'Car moving truck': 0.5077429413795471,
#   'Offroad parking': 0.5317297577857971,
#   'Construction car': 0.5562751889228821,
#   'Construction worker': 0.6858700513839722},
#  'L2ndFloor-D-2022-02-01_T-18_30_01.jpg': {'Barricade': 0.7484570741653442,
#   'Traffic cone': 0.7425377368927002,
#   'Traffic barrel': 0.6702936291694641,
#   'Scaffold': 0.7455428242683411,
#   'Trailer truck': 0.5800721645355225,
#   'Police car': 0.7037659883499146,
#   'Ambulance': 0.6040247678756714,
#   'Firecar': 0.4631221890449524,
#   'Excavator': 0.46816286444664,
#   'Construction truck': 0.5616784691810608,
#   'Car moving truck': 0.5826406478881836,
#   'Offroad parking': 0.4366645812988281,
#   'Construction car': 0.601653516292572,
#   'Construction worker': 0.7977619171142578},
#  'L2ndFloor-D-2022-03-19_T-03_30_01.jpg': {'Barricade': 0.6467514038085938,
#   'Traffic cone': 0.7935917973518372,
#   'Traffic barrel': 0.6461375951766968,
#   'Scaffold': 0.4665602743625641,
#   'Trailer truck': 0.4829164147377014,
#   'Police car': 0.893284022808075,
#   'Ambulance': 0.7177976369857788,
#   'Firecar': 0.5948925614356995,
#   'Excavator': 0.3071576952934265,
#   'Construction truck': 0.45538806915283203,
#   'Car moving truck': 0.501394510269165,
#   'Offroad parking': 0.5335860252380371,
#   'Construction car': 0.5172685980796814,
#   'Construction worker': 0.5993611216545105},
#  'L2ndFloor-D-2022-03-07_T-03_30_01.jpg': {'Barricade': 0.7809464335441589,
#   'Traffic cone': 0.8364507555961609,
#   'Traffic barrel': 0.6967405676841736,
#   'Scaffold': 0.5435892343521118,
#   'Trailer truck': 0.836462676525116,
#   'Police car': 0.8516678214073181,
#   'Ambulance': 0.7420825362205505,
#   'Firecar': 0.572192907333374,
#   'Excavator': 0.3306061625480652,
#   'Construction truck': 0.7815006971359253,
#   'Car moving truck': 0.6392014026641846,
#   'Offroad parking': 0.49680817127227783,
#   'Construction car': 0.5999873280525208,
#   'Construction worker': 0.5853502750396729},
#  'L2ndFloor-D-2022-01-31_T-00_30_01.jpg': {'Barricade': 0.6463812589645386,
#   'Traffic cone': 0.8423463702201843,
#   'Traffic barrel': 0.7010838985443115,
#   'Scaffold': 0.46947890520095825,
#   'Trailer truck': 0.4544864892959595,
#   'Police car': 0.8366320729255676,
#   'Ambulance': 0.6023483276367188,
#   'Firecar': 0.5752882957458496,
#   'Excavator': 0.4832993745803833,
#   'Construction truck': 0.4658612012863159,
#   'Car moving truck': 0.5038641691207886,
#   'Offroad parking': 0.4571473300457001,
#   'Construction car': 0.4986972212791443,
#   'Construction worker': 0.5172125101089478},
#  'L2ndFloor-D-2022-01-09_T-00_00_01.jpg': {'Barricade': 0.7239845991134644,
#   'Traffic cone': 0.851954460144043,
#   'Traffic barrel': 0.7776598930358887,
#   'Scaffold': 0.49568745493888855,
#   'Trailer truck': 0.4426356554031372,
#   'Police car': 0.9003360271453857,
#   'Ambulance': 0.722062885761261,
#   'Firecar': 0.552697479724884,
#   'Excavator': 0.43248066306114197,
#   'Construction truck': 0.5594078898429871,
#   'Car moving truck': 0.48746830224990845,
#   'Offroad parking': 0.5059840083122253,
#   'Construction car': 0.572022557258606,
#   'Construction worker': 0.5838940143585205},
#  'L2ndFloor-D-2022-03-23_T-00_30_02.jpg': {'Barricade': 0.7180930376052856,
#   'Traffic cone': 0.6880623698234558,
#   'Traffic barrel': 0.5803384780883789,
#   'Scaffold': 0.45380082726478577,
#   'Trailer truck': 0.4709452688694,
#   'Police car': 0.7766664624214172,
#   'Ambulance': 0.6796156764030457,
#   'Firecar': 0.593000054359436,
#   'Excavator': 0.31693023443222046,
#   'Construction truck': 0.4622851014137268,
#   'Car moving truck': 0.5230427980422974,
#   'Offroad parking': 0.5291353464126587,
#   'Construction car': 0.5566138029098511,
#   'Construction worker': 0.5450602769851685},
#  'L2ndFloor-D-2022-02-18_T-03_00_01.jpg': {'Barricade': 0.6622087955474854,
#   'Traffic cone': 0.8570573329925537,
#   'Traffic barrel': 0.6781567931175232,
#   'Scaffold': 0.4580520689487457,
#   'Trailer truck': 0.8326538801193237,
#   'Police car': 0.8361877799034119,
#   'Ambulance': 0.7627506256103516,
#   'Firecar': 0.6437199115753174,
#   'Excavator': 0.3295312523841858,
#   'Construction truck': 0.8345102667808533,
#   'Car moving truck': 0.6604725122451782,
#   'Offroad parking': 0.5061777830123901,
#   'Construction car': 0.6066738367080688,
#   'Construction worker': 0.5666665434837341},
#  'L2ndFloor-D-2022-03-21_T-03_00_01.jpg': {'Barricade': 0.6743292212486267,
#   'Traffic cone': 0.7288044095039368,
#   'Traffic barrel': 0.6296162605285645,
#   'Scaffold': 0.4443798363208771,
#   'Trailer truck': 0.4986809194087982,
#   'Police car': 0.9533775448799133,
#   'Ambulance': 0.7056289315223694,
#   'Firecar': 0.5152878761291504,
#   'Excavator': 0.35127705335617065,
#   'Construction truck': 0.5783776044845581,
#   'Car moving truck': 0.5432041883468628,
#   'Offroad parking': 0.523193895816803,
#   'Construction car': 0.5663179159164429,
#   'Construction worker': 0.4907170534133911},
#  'L2ndFloor-D-2022-02-07_T-22_30_01.jpg': {'Barricade': 0.7202235460281372,
#   'Traffic cone': 0.6384872794151306,
#   'Traffic barrel': 0.5605429410934448,
#   'Scaffold': 0.7235108613967896,
#   'Trailer truck': 0.5998750925064087,
#   'Police car': 0.8902978301048279,
#   'Ambulance': 0.7653295993804932,
#   'Firecar': 0.7312237620353699,
#   'Excavator': 0.6460133194923401,
# ...
#   'Ambulance': 0.7472569346427917,
#   'Firecar': 0.5487363934516907,
#   'Excavator': 0.3269513249397278,
#   'Construction truck': 0.4912159740924835,
#   'Car moving truck': 0.5817188620567322,
#   'Offroad parking': 0.4546555280685425,
#   'Construction car': 0.5182468891143799,
#   'Construction worker': 0.5488746762275696},
#  'L2ndFloor-D-2022-02-07_T-03_00_01.jpg': {'Barricade': 0.7252352237701416,
#   'Traffic cone': 0.683742344379425,
#   'Traffic barrel': 0.6194725036621094,
#   'Scaffold': 0.45296159386634827,
#   'Trailer truck': 0.6075153350830078,
#   'Police car': 0.9094096422195435,
#   'Ambulance': 0.7172834277153015,
#   'Firecar': 0.6353245377540588,
#   'Excavator': 0.6782030463218689,
#   'Construction truck': 0.877569854259491,
#   'Car moving truck': 0.6312562823295593,
#   'Offroad parking': 0.45029157400131226,
#   'Construction car': 0.7872395515441895,
#   'Construction worker': 0.7003369331359863},
#  'L2ndFloor-D-2022-02-26_T-18_00_01.jpg': {'Barricade': 0.6969739198684692,
#   'Traffic cone': 0.7373308539390564,
#   'Traffic barrel': 0.6788027882575989,
#   'Scaffold': 0.8838507533073425,
#   'Trailer truck': 0.6426849365234375,
#   'Police car': 0.6180405616760254,
#   'Ambulance': 0.572107195854187,
#   'Firecar': 0.4176900386810303,
#   'Excavator': 0.3493521213531494,
#   'Construction truck': 0.6563253402709961,
#   'Car moving truck': 0.6130623817443848,
#   'Offroad parking': 0.3797721266746521,
#   'Construction car': 0.6373998522758484,
#   'Construction worker': 0.6547860503196716},
#  'L2ndFloor-D-2022-03-01_T-18_00_01.jpg': {'Barricade': 0.750443160533905,
#   'Traffic cone': 0.624575674533844,
#   'Traffic barrel': 0.5551285743713379,
#   'Scaffold': 0.9528436660766602,
#   'Trailer truck': 0.5975707769393921,
#   'Police car': 0.814580500125885,
#   'Ambulance': 0.6364629864692688,
#   'Firecar': 0.5307379961013794,
#   'Excavator': 0.34835782647132874,
#   'Construction truck': 0.7031946778297424,
#   'Car moving truck': 0.6196327209472656,
#   'Offroad parking': 0.5044804215431213,
#   'Construction car': 0.5708243250846863,
#   'Construction worker': 0.6599209904670715},
#  'L2ndFloor-D-2022-01-03_T-14_30_01.jpg': {'Barricade': 0.8154971599578857,
#   'Traffic cone': 0.9288087487220764,
#   'Traffic barrel': 0.8608096241950989,
#   'Scaffold': 0.5361329913139343,
#   'Trailer truck': 0.4572884440422058,
#   'Police car': 0.5851502418518066,
#   'Ambulance': 0.5154026746749878,
#   'Firecar': 0.3894154131412506,
#   'Excavator': 0.33714228868484497,
#   'Construction truck': 0.5126821994781494,
#   'Car moving truck': 0.4962894022464752,
#   'Offroad parking': 0.4307175278663635,
#   'Construction car': 0.5796201229095459,
#   'Construction worker': 0.6095187664031982},
#  'L2ndFloor-D-2022-02-18_T-22_30_01.jpg': {'Barricade': 0.7500050067901611,
#   'Traffic cone': 0.8524199724197388,
#   'Traffic barrel': 0.766118586063385,
#   'Scaffold': 0.8627839684486389,
#   'Trailer truck': 0.6717837452888489,
#   'Police car': 0.8549321293830872,
#   'Ambulance': 0.7626676559448242,
#   'Firecar': 0.5914695262908936,
#   'Excavator': 0.3940156102180481,
#   'Construction truck': 0.8324636220932007,
#   'Car moving truck': 0.7105135917663574,
#   'Offroad parking': 0.4497220516204834,
#   'Construction car': 0.6332374811172485,
#   'Construction worker': 0.6822138428688049},
#  'L2ndFloor-D-2022-03-21_T-22_30_01.jpg': {'Barricade': 0.8020098805427551,
#   'Traffic cone': 0.878802478313446,
#   'Traffic barrel': 0.7347439527511597,
#   'Scaffold': 0.9637708067893982,
#   'Trailer truck': 0.4670916795730591,
#   'Police car': 0.8980454802513123,
#   'Ambulance': 0.7915724515914917,
#   'Firecar': 0.4123656749725342,
#   'Excavator': 0.38270676136016846,
#   'Construction truck': 0.48245325684547424,
#   'Car moving truck': 0.4830637574195862,
#   'Offroad parking': 0.4265177547931671,
#   'Construction car': 0.5581974387168884,
#   'Construction worker': 0.6738434433937073},
#  'L2ndFloor-D-2022-02-10_T-14_00_02.jpg': {'Barricade': 0.7905440926551819,
#   'Traffic cone': 0.8725025653839111,
#   'Traffic barrel': 0.8113716244697571,
#   'Scaffold': 0.9364854693412781,
#   'Trailer truck': 0.62398362159729,
#   'Police car': 0.6999648213386536,
#   'Ambulance': 0.6512039303779602,
#   'Firecar': 0.4298010766506195,
#   'Excavator': 0.4299011528491974,
#   'Construction truck': 0.7521569132804871,
#   'Car moving truck': 0.6860392689704895,
#   'Offroad parking': 0.5068950653076172,
#   'Construction car': 0.6670935750007629,
#   'Construction worker': 0.8381376266479492},
#  'L2ndFloor-D-2022-03-11_T-14_30_02.jpg': {'Barricade': 0.7473973035812378,
#   'Traffic cone': 0.9894858598709106,
#   'Traffic barrel': 0.841168224811554,
#   'Scaffold': 0.9333111643791199,
#   'Trailer truck': 0.7509469985961914,
#   'Police car': 0.773215115070343,
#   'Ambulance': 0.7361846566200256,
#   'Firecar': 0.5085049867630005,
#   'Excavator': 0.5702495574951172,
#   'Construction truck': 0.8285148739814758,
#   'Car moving truck': 0.6580493450164795,
#   'Offroad parking': 0.5078985691070557,
#   'Construction car': 0.7686391472816467,
#   'Construction worker': 0.8739066123962402},
#  'L2ndFloor-D-2022-01-25_T-14_00_01.jpg': {'Barricade': 0.8257749080657959,
#   'Traffic cone': 0.7486175894737244,
#   'Traffic barrel': 0.6738479733467102,
#   'Scaffold': 0.5935778021812439,
#   'Trailer truck': 0.4157465398311615,
#   'Police car': 0.7898114323616028,
#   'Ambulance': 0.5811854600906372,
#   'Firecar': 0.41769272089004517,
#   'Excavator': 0.3485642373561859,
#   'Construction truck': 0.45238661766052246,
#   'Car moving truck': 0.5018088817596436,
#   'Offroad parking': 0.44947242736816406,
#   'Construction car': 0.5309549570083618,
#   'Construction worker': 0.7236964702606201},
#  'L2ndFloor-D-2022-03-07_T-22_00_01.jpg': {'Barricade': 0.7923867702484131,
#   'Traffic cone': 0.8365877270698547,
#   'Traffic barrel': 0.7267224192619324,
#   'Scaffold': 0.923444926738739,
#   'Trailer truck': 0.5745464563369751,
#   'Police car': 0.6949601173400879,
#   'Ambulance': 0.6565305590629578,
#   'Firecar': 0.4078775644302368,
#   'Excavator': 0.44899049401283264,
#   'Construction truck': 0.6292312741279602,
#   'Car moving truck': 0.5613440275192261,
#   'Offroad parking': 0.47360333800315857,
#   'Construction car': 0.5865734815597534,
#   'Construction worker': 0.6666392087936401},
#  'L2ndFloor-D-2022-02-20_T-22_00_01.jpg': {'Barricade': 0.7779772281646729,
#   'Traffic cone': 0.8347185850143433,
#   'Traffic barrel': 0.7271212935447693,
#   'Scaffold': 0.9543505907058716,
#   'Trailer truck': 0.7254294753074646,
#   'Police car': 0.7600789070129395,
#   'Ambulance': 0.627017617225647,
#   'Firecar': 0.4584938883781433,
#   'Excavator': 0.3838660418987274,
#   'Construction truck': 0.8439813852310181,
#   'Car moving truck': 0.6527490615844727,
#   'Offroad parking': 0.5026657581329346,
#   'Construction car': 0.6296582221984863,
#   'Construction worker': 0.6700168251991272},
#  'L2ndFloor-D-2022-02-26_T-00_30_01.jpg': {'Barricade': 0.6262592077255249,
#   'Traffic cone': 0.7466452121734619,
#   'Traffic barrel': 0.5817570686340332,
#   'Scaffold': 0.4591083824634552,
#   'Trailer truck': 0.7421913146972656,
#   'Police car': 0.9989390969276428,
#   'Ambulance': 0.7830514907836914,
#   'Firecar': 0.5712059736251831,
#   'Excavator': 0.30889925360679626,
#   'Construction truck': 0.5753363966941833,
#   'Car moving truck': 0.6212643384933472,
#   'Offroad parking': 0.5483793616294861,
#   'Construction car': 0.5866437554359436,
#   'Construction worker': 0.6159971356391907},
#  'L2ndFloor-D-2022-03-01_T-00_30_01.jpg': {'Barricade': 0.7737575173377991,
#   'Traffic cone': 0.8634962439537048,
#   'Traffic barrel': 0.7336435914039612,
#   'Scaffold': 0.42610228061676025,
#   'Trailer truck': 0.7955586910247803,
#   'Police car': 0.868645191192627,
#   'Ambulance': 0.7403469681739807,
#   'Firecar': 0.5680177211761475,
#   'Excavator': 0.32842934131622314,
#   'Construction truck': 0.8161882162094116,
#   'Car moving truck': 0.6833337545394897,
#   'Offroad parking': 0.5387365221977234,
#   'Construction car': 0.6116160154342651,
#   'Construction worker': 0.6174023747444153},
#  'L2ndFloor-D-2022-01-08_T-18_30_01.jpg': {'Barricade': 0.8072272539138794,
#   'Traffic cone': 0.7304491400718689,
#   'Traffic barrel': 0.7744333744049072,
#   'Scaffold': 0.5910806059837341,
#   'Trailer truck': 0.5649166107177734,
#   'Police car': 0.6759496331214905,
#   'Ambulance': 0.5618905425071716,
#   'Firecar': 0.4610629081726074,
#   'Excavator': 0.4379138648509979,
#   'Construction truck': 0.5571867227554321,
#   'Car moving truck': 0.534311830997467,
#   'Offroad parking': 0.4930904805660248,
#   'Construction car': 0.5905504822731018,
#   'Construction worker': 0.6065694689750671},
#  'L2ndFloor-D-2022-01-29_T-03_30_01.jpg': {'Barricade': 0.7476994395256042,
#   'Traffic cone': 0.8295925855636597,
#   'Traffic barrel': 0.6990621089935303,
#   'Scaffold': 0.6943463087081909,
#   'Trailer truck': 0.7300185561180115,
#   'Police car': 0.8543211817741394,
#   'Ambulance': 0.8774924874305725,
#   'Firecar': 0.648787260055542,
#   'Excavator': 0.40178781747817993,
#   'Construction truck': 0.8170148134231567,
#   'Car moving truck': 0.6914572715759277,
#   'Offroad parking': 0.5048571228981018,
#   'Construction car': 0.676985502243042,
#   'Construction worker': 0.6965867280960083},
#  'L2ndFloor-D-2022-01-30_T-18_00_01.jpg': {'Barricade': 0.6447629332542419,
#   'Traffic cone': 0.8822287917137146,
#   'Traffic barrel': 0.7162761688232422,
#   'Scaffold': 0.6149827241897583,
#   'Trailer truck': 0.47749611735343933,
#   'Police car': 0.7044010758399963,
#   'Ambulance': 0.7097084522247314,
#   'Firecar': 0.45104554295539856,
#   'Excavator': 0.392067015171051,
#   'Construction truck': 0.5386557579040527,
#   'Car moving truck': 0.4899474084377289,
#   'Offroad parking': 0.4682943820953369,
#   'Construction car': 0.5674964785575867,
#   'Construction worker': 0.6265533566474915},
#  'L2ndFloor-D-2022-01-11_T-03_00_01.jpg': {'Barricade': 0.8092449307441711,
#   'Traffic cone': 0.8481588363647461,
#   'Traffic barrel': 0.76645427942276,
#   'Scaffold': 0.5547972917556763,
#   'Trailer truck': 0.4549085199832916,
#   'Police car': 0.9528548121452332,
#   'Ambulance': 0.7385129928588867,
#   'Firecar': 0.5449308156967163,
#   'Excavator': 0.3368183970451355,
#   'Construction truck': 0.47679591178894043,
#   'Car moving truck': 0.4845556616783142,
#   'Offroad parking': 0.4462900161743164,
#   'Construction car': 0.5433792471885681,
#   'Construction worker': 0.6082866787910461},
#  'L2ndFloor-D-2022-03-25_T-03_30_02.jpg': {'Barricade': 0.6597582101821899,
#   'Traffic cone': 0.7897433638572693,
#   'Traffic barrel': 0.6827060580253601,
#   'Scaffold': 0.5389813184738159,
#   'Trailer truck': 0.573455274105072,
#   'Police car': 0.7992289662361145,
#   'Ambulance': 0.68021559715271,
#   'Firecar': 0.6253593564033508,
#   'Excavator': 0.8449515700340271,
#   'Construction truck': 0.8486905694007874,
#   'Car moving truck': 0.6817622780799866,
#   'Offroad parking': 0.460073322057724,
#   'Construction car': 0.7868438363075256,
#   'Construction worker': 0.7483994960784912},
#  'L2ndFloor-D-2021-12-29_T-22_00_01.jpg': {'Barricade': 0.7972655296325684,
#   'Traffic cone': 0.9121143221855164,
#   'Traffic barrel': 0.7820325493812561,
#   'Scaffold': 0.6014480590820312,
#   'Trailer truck': 0.48071524500846863,
#   'Police car': 0.9517349600791931,
#   'Ambulance': 0.7304894924163818,
#   'Firecar': 0.6007639169692993,
#   'Excavator': 0.344931036233902,
#   'Construction truck': 0.48538461327552795,
#   'Car moving truck': 0.5694705247879028,
#   'Offroad parking': 0.45077645778656006,
#   'Construction car': 0.576947033405304,
#   'Construction worker': 0.6458535194396973},
#  'L2ndFloor-D-2022-02-11_T-14_00_01.jpg': {'Barricade': 0.7819976806640625,
#   'Traffic cone': 0.8673216104507446,
#   'Traffic barrel': 0.7966315150260925,
#   'Scaffold': 0.97444748878479,
#   'Trailer truck': 0.7155055999755859,
#   'Police car': 0.8320062160491943,
#   'Ambulance': 0.564003050327301,
#   'Firecar': 0.4887116849422455,
#   'Excavator': 0.5231667160987854,
#   'Construction truck': 0.9177993535995483,
#   'Car moving truck': 0.716303825378418,
#   'Offroad parking': 0.5241875052452087,
#   'Construction car': 0.7304834127426147,
#   'Construction worker': 0.8230609893798828},
#  'L2ndFloor-D-2022-02-04_T-18_00_01.jpg': {'Barricade': 0.8097336888313293,
#   'Traffic cone': 0.870267927646637,
#   'Traffic barrel': 0.7256738543510437,
#   'Scaffold': 0.5725892186164856,
#   'Trailer truck': 0.45984670519828796,
#   'Police car': 0.6993129849433899,
#   'Ambulance': 0.6443906426429749,
#   'Firecar': 0.44784069061279297,
#   'Excavator': 0.3929772973060608,
#   'Construction truck': 0.4890841543674469,
#   'Car moving truck': 0.5032413601875305,
#   'Offroad parking': 0.5107072591781616,
#   'Construction car': 0.5503527522087097,
#   'Construction worker': 0.6947176456451416},
#  'L2ndFloor-D-2022-03-23_T-18_00_01.jpg': {'Barricade': 0.8024282455444336,
#   'Traffic cone': 0.8396826982498169,
#   'Traffic barrel': 0.7582740187644958,
#   'Scaffold': 0.9661086201667786,
#   'Trailer truck': 0.6789981722831726,
#   'Police car': 0.7817578911781311,
#   'Ambulance': 0.6293894648551941,
#   'Firecar': 0.45336538553237915,
#   'Excavator': 0.3454262316226959,
#   'Construction truck': 0.633175790309906,
#   'Car moving truck': 0.664274275302887,
#   'Offroad parking': 0.4288904368877411,
#   'Construction car': 0.6082201600074768,
#   'Construction worker': 0.6938362121582031},
#  'L2ndFloor-D-2022-03-02_T-03_00_01.jpg': {'Barricade': 0.7364299893379211,
#   'Traffic cone': 0.8273658752441406,
#   'Traffic barrel': 0.6491531729698181,
#   'Scaffold': 0.508836030960083,
#   'Trailer truck': 0.7780033349990845,
#   'Police car': 0.9942143559455872,
#   'Ambulance': 0.7027400135993958,
#   'Firecar': 0.5684482455253601,
#   'Excavator': 0.35429713129997253,
#   'Construction truck': 0.8591746091842651,
#   'Car moving truck': 0.6920849084854126,
#   'Offroad parking': 0.48967626690864563,
#   'Construction car': 0.6688058376312256,
#   'Construction worker': 0.5835239887237549},
#  'L2ndFloor-D-2022-02-25_T-03_00_01.jpg': {'Barricade': 0.7502061128616333,
#   'Traffic cone': 0.8879797458648682,
#   'Traffic barrel': 0.7364264726638794,
#   'Scaffold': 0.460130512714386,
#   'Trailer truck': 0.5450084805488586,
#   'Police car': 0.8779008984565735,
#   'Ambulance': 0.7432323694229126,
#   'Firecar': 0.6773856282234192,
#   'Excavator': 0.33251112699508667,
#   'Construction truck': 0.6545101404190063,
#   'Car moving truck': 0.5540269017219543,
#   'Offroad parking': 0.5717684030532837,
#   'Construction car': 0.6228169202804565,
#   'Construction worker': 0.5930490493774414},
#  'L2ndFloor-D-2022-03-05_T-18_30_01.jpg': {'Barricade': 0.819210946559906,
#   'Traffic cone': 0.8863257765769958,
#   'Traffic barrel': 0.7354516983032227,
#   'Scaffold': 0.9585224390029907,
#   'Trailer truck': 0.7077087759971619,
#   'Police car': 0.7617210149765015,
#   'Ambulance': 0.5709003806114197,
#   'Firecar': 0.5096558928489685,
#   'Excavator': 0.3714860677719116,
#   'Construction truck': 0.84195876121521,
#   'Car moving truck': 0.6077642440795898,
#   'Offroad parking': 0.489396870136261,
#   'Construction car': 0.651027500629425,
#   'Construction worker': 0.6455419659614563},
#  'L2ndFloor-D-2022-02-22_T-18_30_01.jpg': {'Barricade': 0.7534042596817017,
#   'Traffic cone': 0.789914071559906,
#   'Traffic barrel': 0.648036003112793,
#   'Scaffold': 0.9617008566856384,
#   'Trailer truck': 0.5069193840026855,
#   'Police car': 0.8307808041572571,
#   'Ambulance': 0.6695634722709656,
#   'Firecar': 0.46154117584228516,
#   'Excavator': 0.34742510318756104,
#   'Construction truck': 0.5712565779685974,
#   'Car moving truck': 0.655560314655304,
#   'Offroad parking': 0.5114883780479431,
#   'Construction car': 0.6068992614746094,
#   'Construction worker': 0.6811277866363525},
#  'L2ndFloor-D-2022-02-03_T-03_30_01.jpg': {'Barricade': 0.6611951589584351,
#   'Traffic cone': 0.8730771541595459,
#   'Traffic barrel': 0.6885272264480591,
#   'Scaffold': 0.47844213247299194,
#   'Trailer truck': 0.4606423079967499,
#   'Police car': 0.7506251931190491,
#   'Ambulance': 0.6861987113952637,
#   'Firecar': 0.6373729109764099,
#   'Excavator': 0.376965194940567,
#   'Construction truck': 0.4630029499530792,
#   'Car moving truck': 0.4853961169719696,
#   'Offroad parking': 0.4997767508029938,
#   'Construction car': 0.5150477290153503,
#   'Construction worker': 0.5827110409736633},
#  ...}

# %%
import pickle

# Save
with open('../out_ram.pkl', 'wb') as f:
    pickle.dump(results, f)
